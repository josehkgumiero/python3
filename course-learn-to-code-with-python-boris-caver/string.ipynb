# %%
"sushi"
# Out:
# 'sushi'

# %%
'sushi'
# Out:
# 'sushi'

# %%
"warriosfan123!"
# Out:
# 'warriosfan123!'

# %%
"$5.00"
# Out:
# '$5.00'

# %%
"1"
# Out:
# '1'

# %%
"You're right"
# Out:
# "You're right"

# %%
print("You're right")
# Out:
# You're right

# %%
'Shakespare once wrote "To be or not be" in one of his plays'
# Out:
# 'Shakespare once wrote "To be or not be" in one of his plays'

# %%
" "
# Out:
# ' '

# %%
""
# Out:
# ''

# %%
''
# Out:
# ''

# %%
"5"
# Out:
# '5'

# %%
5
# Out:
# 5

# %%
print("""Hello
my name is 
Boris
""")
# Out:
# Hello
# my name is
# Boris

# %%
"""Hello
my name is 
Boris
"""
# Out:
# 'Hello\nmy name is \nBoris\n'

# %%
print('Hello\nmy name is \nBoris\n')
# Out:
# Hello
# my name is
# Boris

# %%
len("Python")
# Out:
# 6

# %%
"José" + "Gumiero"
# Out:
# 'JoséGumiero'

# %%
"a" "b" "c"
# Out:
# 'abc'

# %%
"---"*30
# Out:
# '------------------------------------------------------------------------------------------'

# %%
best_language_ever = "Python"

# %%
print(best_language_ever[0])
print(best_language_ever[1])
print(best_language_ever[2])
print(best_language_ever[3])
print(best_language_ever[2*2])
print(best_language_ever[5])
# Out:
# P
# y
# t
# h
# o
# n

# %%
topic = "programming"

# %%
print(topic[-1])
print(topic[-2])
print(topic[-3])
print(topic[-100])
# Out:
# g
# n
# i
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[35], line 4
#       2 print(topic[-2])
#       3 print(topic[-3])
# ----> 4 print(topic[-100])
#
# IndexError: string index out of range

# %%
address = "Attractive street, Bervely Hills, CA 90210"

# %%
address[0:3]
# Out:
# 'Att'

# %%
address[17:32]
# Out:
# ', Bervely Hills'

# %%
address[10:100]
# Out:
# ' street, Bervely Hills, CA 90210'

# %%
len(address)
# Out:
# 42

# %%
address[34:-6]
# Out:
# 'CA'

# %%
address[32:-6]
# Out:
# ', CA'

# %%
address[-8:-6]
# Out:
# 'CA'

# %%
alphabet = "abcdefghijklmnopqrstuvwxyz"

# %%
alphabet[0:10:3]
# Out:
# 'adgj'

# %%
alphabet[-20:-1:2]
# Out:
# 'gikmoqsuwy'

# %%
print("This will \nbegin on a \nnew line")
# Out:
# This will
# begin on a
# new line

# %%
print("\tOnce upon a time")
# Out:
# 	Once upon a time

# %%
print("\"To be or not to be\", said Hamlet")
# Out:
# "To be or not to be", said Hamlet

# %%
print("\'To be or not to be\', said Hamlet")
# Out:
# 'To be or not to be', said Hamlet

# %%
print("Let's print a backslash: \\")
# Out:
# Let's print a backslash: \

# %%
file_name = r"C:\news\travel"

# %%
print(file_name)
# Out:
# C:\news\travel

# %%
announcement = "The winners of the prize are Boris, Andy and Adam"

# %%
"Boris" in announcement
# Out:
# True

# %%
"Steve" in announcement
# Out:
# False

# %%
browser = "Google Chrome"

# %%
browser.find("C")
# Out:
# 7

# %%
browser.find("o")
# Out:
# 1

# %%
browser.find("G")
# Out:
# 0

# %%
browser.index("G")
# Out:
# 0

# %%
browser.find("o", 2)
# Out:
# 2

# %%
browser.find("o", 3)
# Out:
# 10

# %%
solution = "Mr. Kermit the Frog"

# %%
solution.startswith("M")
# Out:
# True

# %%
solution.startswith("Mr. K")
# Out:
# True

# %%
solution.startswith("R")
# Out:
# False

# %%
solution.endswith("Frog")
# Out:
# True

# %%
word = "queueing"

# %%
word.count("ue")
# Out:
# 2

# %%
story = "once upon a time"

# %%
story.capitalize()
# Out:
# 'Once upon a time'

# %%
story.title()
# Out:
# 'Once Upon A Time'

# %%
story.upper()
# Out:
# 'ONCE UPON A TIME'

# %%
"HELLO".lower()
# Out:
# 'hello'

# %%
"AbCdE".swapcase()
# Out:
# 'aBcDe'

# %%
"BENJAMIN FRANLIN".lower().title()
# Out:
# 'Benjamin Franlin'

# %%
"winter".islower()
# Out:
# True

# %%
"winter 12#$".islower()
# Out:
# True

# %%
"Winter 12#$".islower()
# Out:
# False

# %%
"SUMMER #$".isupper()
# Out:
# True

# %%
"sUMMER".isupper()
# Out:
# False

# %%
"The Four Seasons".istitle()
# Out:
# True

# %%
"The 4 Seasons".istitle()
# Out:
# True

# %%
"The four Seasons".istitle()
# Out:
# False

# %%
"area".isalpha()
# Out:
# True

# %%
"area 51".isalpha()
# Out:
# False

# %%
"51".isnumeric()
# Out:
# True

# %%
"area 51".isnumeric()
# Out:
# False

# %%
"area51".isalnum()
# Out:
# True

# %%
"area 51".isalnum()
# Out:
# False

# %%
" ".isspace()
# Out:
# True

# %%
" k ".isspace()
# Out:
# False

# %%
empty_space = "         content         "

# %%
empty_space.rstrip()
# Out:
# '         content'

# %%
empty_space.lstrip()
# Out:
# 'content         '

# %%
empty_space.strip()
# Out:
# 'content'

# %%
website = "www.python.org"

# %%
website.lstrip("w")
# Out:
# '.python.org'

# %%
website.rstrip("org")
# Out:
# 'www.python.'

# %%
website.strip("worg.")
# Out:
# 'python'

# %%
phone_number = "555 555 1234"

# %%
phone_number.replace(" ", "-")
# Out:
# '555-555-1234'

# %%
phone_number.replace("5", "9")
# Out:
# '999 999 1234'

# %%
phone_number
# Out:
# '555 555 1234'

# %%
phone_number = phone_number.replace(" ", "-")

# %%
phone_number
# Out:
# '555-555-1234'

# %%
mad_libs = "{} laughed at the {} {}."

# %%
mad_libs.format("Bobby", "green", "alien")
# Out:
# 'Bobby laughed at the green alien.'

# %%
mad_libs = "{2} laughed at the {1} {0}"

# %%
mad_libs.format("Jennifer","silly","tomato")
# Out:
# 'tomato laughed at the silly Jennifer'

# %%
mad_libs = "{name} laughed at the {adjective} {noun}"

# %%
mad_libs.format(name = "Bobby", adjective = "green", noun = "alien")
# Out:
# 'Bobby laughed at the green alien'

# %%
name = "Bobby"

# %%
adjective = "green"

# %%
noun = "alien"

# %%
mad_libs = f"{name} laughed at the {adjective} {noun}."

# %%
mad_libs
# Out:
# 'Bobby laughed at the green alien.'
