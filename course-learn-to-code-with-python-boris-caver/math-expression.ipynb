# %%
print(3+4)

# %%
print(3.5+6.3)

# %%
print(10-5)

# %%
print(5*3)

# %%
print("Ba"+"con")

# %%
print("lolo"*32)

# %%
print(10+3.0)

# %%
print(5**3)
# Out:
# 125

# %%
print(4**4)
# Out:
# 256

# %%
print(3+5*3)
# Out:
# 18

# %%
print((3+5)*3)
# Out:
# 24

# %%
print(15/3)
# Out:
# 5.0

# %%
print(14/3)
# Out:
# 4.666666666666667

# %%
print(14 // 3)
# Out:
# 4

# %%
print(-14 // 3)
# Out:
# -5

# %%
print(14 % 3)
# Out:
# 2

# %%
print(15 % 3)
# Out:
# 0

# %%
print(16%3)
# Out:
# 1

# %%
print(1 % 3)
# Out:
# 1

# %%
print(2%3)
# Out:
# 2

# %%
print(3%3)
# Out:
# 0
