# %%
int(3.14)
# Out:
# 3

# %%
int(3.99)
# Out:
# 3

# %%
int("3")
# Out:
# 3

# %%
int(3)
# Out:
# 3

# %%
float(5)
# Out:
# 5.0

# %%
float("10.32")
# Out:
# 10.32

# %%
float(5.32)
# Out:
# 5.32

# %%
str(5.35)
# Out:
# '5.35'

# %%
str(5)
# Out:
# '5'

# %%
str('Hello')
# Out:
# 'Hello'

# %%
str(5) + "hello"
# Out:
# '5hello'

# %%
3+3
# Out:
# 6

# %%
4.3+5.7
# Out:
# 10.0

# %%
3+5.8
