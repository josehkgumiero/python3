# %%
a = 3

# %%
a
# Out:
# 3

# %%
a = 10

# %%
a
# Out:
# 10

# %%
a = "hello"

# %%
a
# Out:
# 'hello'

# %%
a = [1,2, 3]

# %%
a
# Out:
# [1, 2, 3]

# %%
a = 3

# %%
b = a

# %%
a = 5

# %%
a
# Out:
# 5

# %%
b
# Out:
# 3

# %%
a = [1, 2, 3]

# %%
b = a

# %%
a.append(4)

# %%
a
# Out:
# [1, 2, 3, 4]

# %%
b
# Out:
# [1, 2, 3, 4]

# %%
students = ["Bob", "Saily", "Sue"]
athletes = students
nerds = ["Bob", "Saily", "Sue"]

# %%
students == athletes
# Out:
# True

# %%
students == nerds
# Out:
# True

# %%
students is athletes
# Out:
# True

# %%
students is nerds
# Out:
# False

# %%
a = 1
b = 1

# %%
a == b
# Out:
# True

# %%
a is b
# Out:
# True

# %%
a = 3.14
b = 3.14

# %%
a == b
# Out:
# True

# %%
a is b
# Out:
# False

# %%
a= "hello"

# %%
b = "hello"

# %%
a == b
# Out:
# True

# %%
a is b
# Out:
# True

# %%
a = [1, 2, 3]

# %%
b = a[:]

# %%
a == b
# Out:
# True

# %%
a is b
# Out:
# False

# %%
import copy

# %%
c = a.copy()

# %%
a == c
# Out:
# True

# %%
a is c
# Out:
# False

# %%
d = copy.copy(a)

# %%
a == d
# Out:
# True

# %%
a is d
# Out:
# False

# %%
numbers = [2, 3, 4]

# %%
a = [1, numbers, 5]

# %%
b = a[:]

# %%
b = a.copy()

# %%
b= copy.copy(a)

# %%
a == b
# Out:
# True

# %%
a is b
# Out:
# False

# %%
a[1] is b [1]
# Out:
# True

# %%
a[1].append(100)

# %%
print(b)
# Out:
# [1, [2, 3, 4, 100], 5]

# %%
b = copy.deepcopy(a)

# %%
a == b
# Out:
# True

# %%
a is b
# Out:
# False

# %%
a[1] is b[1]
# Out:
# False
