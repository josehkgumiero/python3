# %%
def output_text():
    print("Welcome to the program!")
    print("It's nice to meet you")
    print("Have an excellent day programming!")

# %%
output_text()
# Out:
# Welcome to the program!
# It's nice to meet you
# Have an excellent day programming!

# %%
output_text
# Out:
# <function __main__.output_text()>

# %%
def p(text):
    print(text)

# %%
p("hello")
# Out:
# hello

# %%
p("goodbye")
# Out:
# goodbye

# %%
p("ok")
# Out:
# ok

# %%
def add(a, b):
    print("The sum is", a+b)

# %%
add(3,5)
# Out:
# The sum is 8

# %%
add(-4,7)
# Out:
# The sum is 3

# %%
add(1, 1, 1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 add(1, 1, 1)
#
# TypeError: add() takes 2 positional arguments but 3 were given

# %%
def add3(a, b, c):
    print("The sum is", a+b+c)

# %%
add3(5, 10, 15)
# Out:
# The sum is 30

# %%
add3(a=5, c=10, b=15)
# Out:
# The sum is 30

# %%
def add2(a, b):
    return a+b

# %%
add2(10,10)
# Out:
# 20

# %%
def add4(a=0,b=1,c=2,d=3):
    return a+b+c+d

# %%
add4(c=10)
# Out:
# 14

# %%
a = None

# %%
type(a)
# Out:
# NoneType

# %%
def subtract(a, b):
    print(a-b)

# %%
result = subtract(5, 3)
# Out:
# 2

# %%
print(result)
# Out:
# None

# %%
result

# %%
def word_multipler(word: str, time: int) -> str:
    return word * time

# %%
word_multipler("10", 5)
# Out:
# '1010101010'

# %%
word_multipler(10, 5)
# Out:
# 50
