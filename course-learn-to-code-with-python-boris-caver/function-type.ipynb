# %%
type(5)
# Out:
# int

# %%
type(10)
# Out:
# int

# %%
type(3.0)
# Out:
# float

# %%
type(5.0)
# Out:
# float

# %%
type("computer")
# Out:
# str

# %%
type("laptop")
# Out:
# str

# %%
type(5) == type(10)
# Out:
# True

# %%
type("computer")==type("laptop")
# Out:
# True

# %%
type(5) == type(5.0)
# Out:
# False

# %%
type(5) == type("5")
# Out:
# False

# %%
type(True)
# Out:
# bool

# %%
type(False)
# Out:
# bool

# %%
type(True) == type(False)
# Out:
# True

# %%
type([1, 2, 3])
# Out:
# list

# %%
type({"NJ": "Treton"})
# Out:
# dict
