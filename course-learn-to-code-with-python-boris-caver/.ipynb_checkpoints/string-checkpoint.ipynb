# %%
"sushi"
# Out:
# 'sushi'

# %%
'sushi'
# Out:
# 'sushi'

# %%
"warriosfan123!"
# Out:
# 'warriosfan123!'

# %%
"$5.00"
# Out:
# '$5.00'

# %%
"1"
# Out:
# '1'

# %%
"You're right"
# Out:
# "You're right"

# %%
print("You're right")
# Out:
# You're right

# %%
'Shakespare once wrote "To be or not be" in one of his plays'
# Out:
# 'Shakespare once wrote "To be or not be" in one of his plays'

# %%
" "
# Out:
# ' '

# %%
""
# Out:
# ''

# %%
''
# Out:
# ''

# %%
"5"
# Out:
# '5'

# %%
5
# Out:
# 5

# %%
print("""Hello
my name is 
Boris
""")
# Out:
# Hello
# my name is
# Boris

# %%
"""Hello
my name is 
Boris
"""
# Out:
# 'Hello\nmy name is \nBoris\n'

# %%
print('Hello\nmy name is \nBoris\n')
# Out:
# Hello
# my name is
# Boris
