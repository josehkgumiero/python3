# %%
print("I love sandwiches")
# Out:
# I love sandwiches

# %%
print('I aslso love juice beverage')
# Out:
# I aslso love juice beverage

# %%
print("We're working with Python")
# Out:
# We're working with Python

# %%
print(5)
# Out:
# 5

# %%
print(3+4)
# Out:
# 7

# %%
print(10-8)
# Out:
# 2

# %%
print("3 + 4")
# Out:
# 3 + 4

# %%
print("3"+"4")
# Out:
# 34

# %%
print("A", "B")
# Out:
# A B

# %%
print("C", "D", "E", "F")
# Out:
# C D E F

# %%
print(5+3, 2-8)
# Out:
# 8 -6

# %%
print(5+3, 2-8, 3+1)
# Out:
# 8 -6 4

# %%
print("Hello", 10, 3.14)
# Out:
# Hello 10 3.14

# %%
print("ABC", "DEF", "XYZ")
# Out:
# ABC DEF XYZ

# %%
print("ABC", "DEF", "XYZ", sep="!")
# Out:
# ABC!DEF!XYZ

# %%
print("ABC", "DEF", "XYZ", sep="--*--")
# Out:
# ABC--*--DEF--*--XYZ

# %%
print("ABC", "DEF", "XYZ", sep=" ")
# Out:
# ABC DEF XYZ

# %%
print("ABC", "DEF", "XYZ", "!")
# Out:
# ABC DEF XYZ !

# %%
print("ABC", "DEF", "XYZ", end="!&*")
print("HELLO")
# Out:
# ABC DEF XYZ!&*HELLO

# %%
print("ABC", "DEF", "XYZ", sep="**", end="#")
# Out:
# ABC**DEF**XYZ#

# %%
print("ABC", "DEF", "XYZ", sep="#", end="**")
# Out:
# ABC#DEF#XYZ**
