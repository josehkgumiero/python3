# %%
True
# Out:
# True

# %%
print(True)
# Out:
# True

# %%
False
# Out:
# False

# %%
print(False)
# Out:
# False

# %%
"True"
# Out:
# 'True'

# %%
"False"
# Out:
# 'False'

# %%
5 == 5
# Out:
# True

# %%
5 == 8
# Out:
# False

# %%
8.3 == 8.3
# Out:
# True

# %%
8.3 == 4.1
# Out:
# False

# %%
5 == "5"
# Out:
# False

# %%
"ham"== "ham"
# Out:
# True

# %%
"ham"=="bacon"
# Out:
# False

# %%
"ham"=="Ham"
# Out:
# False

# %%
"5"=="5"
# Out:
# True

# %%
"" == ""
# Out:
# True

# %%
"!==*" == "!==*"
# Out:
# True

# %%
5 == 5.0
# Out:
# True

# %%
5 == 5.1
# Out:
# False

# %%
True == True
# Out:
# True

# %%
True == False
# Out:
# False

# %%
False == False
# Out:
# True

# %%
10 != 8
# Out:
# True

# %%
10 != 10
# Out:
# False

# %%
"music" != "music"
# Out:
# False

# %%
"music" != "noise"
# Out:
# True

# %%
"music" != "Music"
# Out:
# True

# %%
10 != "10"
# Out:
# True

# %%
8.3 != 9.6
# Out:
# True

# %%
3.0 != 3
# Out:
# False

# %%
5 < 8
# Out:
# True

# %%
10 < 7
# Out:
# False

# %%
8 <= 8
# Out:
# True

# %%
8 <= 11
# Out:
# True

# %%
8 <= 7
# Out:
# False

# %%
9 > 5
# Out:
# True

# %%
10 > 20
# Out:
# False

# %%
9 >= 9
# Out:
# True

# %%
9 >= 5
# Out:
# True

# %%
9 >= 10
# Out:
# False

# %%
5 < 8 <= 10
# Out:
# True

# %%
5 < 8 <= 7
# Out:
# False
