# %%
name = "José"

# %%
age = 29

# %%
handsome = True

# %%
favorite_language = "Python"

# %%
name
# Out:
# 'José'

# %%
age
# Out:
# 29

# %%
handsome
# Out:
# True

# %%
favorite_language
# Out:
# 'Python'

# %%
age+4
# Out:
# 33

# %%
print("My name is", name, "and I am", age, "yers old")
# Out:
# My name is José and I am 29 yers old

# %%
text = f"My name is {name}, and I am {age} yers old"

# %%
text
# Out:
# 'My name is José, and I am 29 yers old'

# %%
age = 23

# %%
age
# Out:
# 23

# %%
age = 27 + 10

# %%
age
# Out:
# 37

# %%
fact_or_fiction = 6 < 10

# %%
fact_or_fiction
# Out:
# True

# %%
chamaleon = 5

# %%
chamaleon
# Out:
# 5

# %%
chamaleon = "some string"

# %%
chamaleon
# Out:
# 'some string'

# %%
chamaleon = 9.99

# %%
chamaleon
# Out:
# 9.99

# %%
chamaleon = False

# %%
chamaleon
# Out:
# False

# %%
a = 5

# %%
b = 4

# %%
a = b = 5

# %%
b = 10

# %%
a
# Out:
# 5

# %%
b
# Out:
# 10

# %%
a, b = 10, 5

# %%
a
# Out:
# 10

# %%
b
# Out:
# 5

# %%
a, b, c = 5, 10, 13

# %%
a
# Out:
# 5

# %%
b
# Out:
# 10

# %%
c
# Out:
# 13

# %%
a = 1

# %%
a = a + 2

# %%
a
# Out:
# 3

# %%
a = 1

# %%
a += 2

# %%
a
# Out:
# 3

# %%
word = "race"

# %%
word = word + "car"

# %% [raw]
# word

# %%
word = "race"

# %%
word += "car"

# %%
word
# Out:
# 'racecar'

# %%
b = 5

# %%
b = b * 3

# %%
b
# Out:
# 15

# %%
b = 5

# %%
b *= 3

# %%
b
# Out:
# 15
